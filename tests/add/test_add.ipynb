# %%
import sys
sys.path.append("../../")
from cloth.neo4j_graph import Neo4jGraphstore as Graphstore


graph = Graphstore()

# %%
# Prepare
from langchain.docstore.document import Document
from textwrap import dedent
text = dedent("""
The biggest lesson that can be read from 70 years of AI research is that general methods that leverage computation are ultimately the most effective, and by a large margin. The ultimate reason for this is Moore's law, or rather its generalization of continued exponentially falling cost per unit of computation. Most AI research has been conducted as if the computation available to the agent were constant (in which case leveraging human knowledge would be one of the only ways to improve performance) but, over a slightly longer time than a typical research project, massively more computation inevitably becomes available. Seeking an improvement that makes a difference in the shorter term, researchers seek to leverage their human knowledge of the domain, but the only thing that matters in the long run is the leveraging of computation. These two need not run counter to each other, but in practice they tend to. Time spent on one is time not spent on the other. There are psychological commitments to investment in one approach or the other. And the human-knowledge approach tends to complicate methods in ways that make them less suited to taking advantage of general methods leveraging computation.  There were many examples of AI researchers' belated learning of this bitter lesson, and it is instructive to review some of the most prominent.
>>
In computer chess, the methods that defeated the world champion, Kasparov, in 1997, were based on massive, deep search. At the time, this was looked upon with dismay by the majority of computer-chess researchers who had pursued methods that leveraged human understanding of the special structure of chess. When a simpler, search-based approach with special hardware and software proved vastly more effective, these human-knowledge-based chess researchers were not good losers. They said that ``brute force" search may have won this time, but it was not a general strategy, and anyway it was not how people played chess. These researchers wanted methods based on human input to win and were disappointed when they did not.
>>
A similar pattern of research progress was seen in computer Go, only delayed by a further 20 years. Enormous initial efforts went into avoiding search by taking advantage of human knowledge, or of the special features of the game, but all those efforts proved irrelevant, or worse, once search was applied effectively at scale. Also important was the use of learning by self play to learn a value function (as it was in many other games and even in chess, although learning did not play a big role in the 1997 program that first beat a world champion). Learning by self play, and learning in general, is like search in that it enables massive computation to be brought to bear. Search and learning are the two most important classes of techniques for utilizing massive amounts of computation in AI research. In computer Go, as in computer chess, researchers' initial effort was directed towards utilizing human understanding (so that less search was needed) and only much later was much greater success had by embracing search and learning.
>>
In speech recognition, there was an early competition, sponsored by DARPA, in the 1970s. Entrants included a host of special methods that took advantage of human knowledge---knowledge of words, of phonemes, of the human vocal tract, etc. On the other side were newer methods that were more statistical in nature and did much more computation, based on hidden Markov models (HMMs). Again, the statistical methods won out over the human-knowledge-based methods. This led to a major change in all of natural language processing, gradually over decades, where statistics and computation came to dominate the field. The recent rise of deep learning in speech recognition is the most recent step in this consistent direction. Deep learning methods rely even less on human knowledge, and use even more computation, together with learning on huge training sets, to produce dramatically better speech recognition systems. As in the games, researchers always tried to make systems that worked the way the researchers thought their own minds worked---they tried to put that knowledge in their systems---but it proved ultimately counterproductive, and a colossal waste of researcher's time, when, through Moore's law, massive computation became available and a means was found to put it to good use.
>>
In computer vision, there has been a similar pattern. Early methods conceived of vision as searching for edges, or generalized cylinders, or in terms of SIFT features. But today all this is discarded. Modern deep-learning neural networks use only the notions of convolution and certain kinds of invariances, and perform much better.
>>
This is a big lesson. As a field, we still have not thoroughly learned it, as we are continuing to make the same kind of mistakes. To see this, and to effectively resist it, we have to understand the appeal of these mistakes. We have to learn the bitter lesson that building in how we think we think does not work in the long run. The bitter lesson is based on the historical observations that 1) AI researchers have often tried to build knowledge into their agents, 2) this always helps in the short term, and is personally satisfying to the researcher, but 3) in the long run it plateaus and even inhibits further progress, and 4) breakthrough progress eventually arrives by an opposing approach based on scaling computation by search and learning. The eventual success is tinged with bitterness, and often incompletely digested, because it is success over a favored, human-centric approach.
>>
One thing that should be learned from the bitter lesson is the great power of general purpose methods, of methods that continue to scale with increased computation even as the available computation becomes very great. The two methods that seem to scale arbitrarily in this way are search and learning.
>>
The second general point to be learned from the bitter lesson is that the actual contents of minds are tremendously, irredeemably complex; we should stop trying to find simple ways to think about the contents of minds, such as simple ways to think about space, objects, multiple agents, or symmetries. All these are part of the arbitrary, intrinsically-complex, outside world. They are not what should be built in, as their complexity is endless; instead we should build in only the meta-methods that can find and capture this arbitrary complexity. Essential to these methods is that they can find good approximations, but the search for them should be by our methods, not by us. We want AI agents that can discover like we can, not which contain what we have discovered. Building in our discoveries only makes it harder to see how the discovering process can be done.\
""")

documents = [Document(page_content=ex.strip()) for ex in text.split(">>")]
len(documents)
# Out:
# 8

# %%
# Add 
graph.add(documents)
# Out:
# DEBUG:    neo4j_graph.py/extract_relations -> 8 Relations generated in 2.6822803020477295
# DEBUG:    neo4j_graph.py/add -> Documents and Relations added in 6.461272954940796
# {'documents': [Document(page_content="The biggest lesson that can be read from 70 years of AI research is that general methods that leverage computation are ultimately the most effective, and by a large margin. The ultimate reason for this is Moore's law, or rather its generalization of continued exponentially falling cost per unit of computation. Most AI research has been conducted as if the computation available to the agent were constant (in which case leveraging human knowledge would be one of the only ways to improve performance) but, over a slightly longer time than a typical research project, massively more computation inevitably becomes available. Seeking an improvement that makes a difference in the shorter term, researchers seek to leverage their human knowledge of the domain, but the only thing that matters in the long run is the leveraging of computation. These two need not run counter to each other, but in practice they tend to. Time spent on one is time not spent on the other. There are psychological commitments to investment in one approach or the other. And the human-knowledge approach tends to complicate methods in ways that make them less suited to taking advantage of general methods leveraging computation.  There were many examples of AI researchers' belated learning of this bitter lesson, and it is instructive to review some of the most prominent.", metadata={'page_content': "The biggest lesson that can be read from 70 years of AI research is that general methods that leverage computation are ultimately the most effective, and by a large margin. The ultimate reason for this is Moore's law, or rather its generalization of continued exponentially falling cost per unit of computation. Most AI research has been conducted as if the computation available to the agent were constant (in which case leveraging human knowledge would be one of the only ways to improve performance) but, over a slightly longer time than a typical research project, massively more computation inevitably becomes available. Seeking an improvement that makes a difference in the shorter term, researchers seek to leverage their human knowledge of the domain, but the only thing that matters in the long run is the leveraging of computation. These two need not run counter to each other, but in practice they tend to. Time spent on one is time not spent on the other. There are psychological commitments to investment in one approach or the other. And the human-knowledge approach tends to complicate methods in ways that make them less suited to taking advantage of general methods leveraging computation.  There were many examples of AI researchers' belated learning of this bitter lesson, and it is instructive to review some of the most prominent.", 'type': 'Document', 'id': 'b9ac056066f1d8107fc8ebbd9871349d28f73d62f348deb5c203bce91b206ba1'}),
#   Document(page_content='In computer chess, the methods that defeated the world champion, Kasparov, in 1997, were based on massive, deep search. At the time, this was looked upon with dismay by the majority of computer-chess researchers who had pursued methods that leveraged human understanding of the special structure of chess. When a simpler, search-based approach with special hardware and software proved vastly more effective, these human-knowledge-based chess researchers were not good losers. They said that ``brute force" search may have won this time, but it was not a general strategy, and anyway it was not how people played chess. These researchers wanted methods based on human input to win and were disappointed when they did not.', metadata={'page_content': 'In computer chess, the methods that defeated the world champion, Kasparov, in 1997, were based on massive, deep search. At the time, this was looked upon with dismay by the majority of computer-chess researchers who had pursued methods that leveraged human understanding of the special structure of chess. When a simpler, search-based approach with special hardware and software proved vastly more effective, these human-knowledge-based chess researchers were not good losers. They said that ``brute force" search may have won this time, but it was not a general strategy, and anyway it was not how people played chess. These researchers wanted methods based on human input to win and were disappointed when they did not.', 'type': 'Document', 'id': '10efa6ae491957561961a8cc5f3daa9e995354aa2caaaabc19c1bbb0ba10639c'}),
#   Document(page_content="A similar pattern of research progress was seen in computer Go, only delayed by a further 20 years. Enormous initial efforts went into avoiding search by taking advantage of human knowledge, or of the special features of the game, but all those efforts proved irrelevant, or worse, once search was applied effectively at scale. Also important was the use of learning by self play to learn a value function (as it was in many other games and even in chess, although learning did not play a big role in the 1997 program that first beat a world champion). Learning by self play, and learning in general, is like search in that it enables massive computation to be brought to bear. Search and learning are the two most important classes of techniques for utilizing massive amounts of computation in AI research. In computer Go, as in computer chess, researchers' initial effort was directed towards utilizing human understanding (so that less search was needed) and only much later was much greater success had by embracing search and learning.", metadata={'page_content': "A similar pattern of research progress was seen in computer Go, only delayed by a further 20 years. Enormous initial efforts went into avoiding search by taking advantage of human knowledge, or of the special features of the game, but all those efforts proved irrelevant, or worse, once search was applied effectively at scale. Also important was the use of learning by self play to learn a value function (as it was in many other games and even in chess, although learning did not play a big role in the 1997 program that first beat a world champion). Learning by self play, and learning in general, is like search in that it enables massive computation to be brought to bear. Search and learning are the two most important classes of techniques for utilizing massive amounts of computation in AI research. In computer Go, as in computer chess, researchers' initial effort was directed towards utilizing human understanding (so that less search was needed) and only much later was much greater success had by embracing search and learning.", 'type': 'Document', 'id': 'e6efc0853c160282f3d415491b814ef62b6e9ea84015f8e6ce28bc45168b38dc'}),
#   Document(page_content="In speech recognition, there was an early competition, sponsored by DARPA, in the 1970s. Entrants included a host of special methods that took advantage of human knowledge---knowledge of words, of phonemes, of the human vocal tract, etc. On the other side were newer methods that were more statistical in nature and did much more computation, based on hidden Markov models (HMMs). Again, the statistical methods won out over the human-knowledge-based methods. This led to a major change in all of natural language processing, gradually over decades, where statistics and computation came to dominate the field. The recent rise of deep learning in speech recognition is the most recent step in this consistent direction. Deep learning methods rely even less on human knowledge, and use even more computation, together with learning on huge training sets, to produce dramatically better speech recognition systems. As in the games, researchers always tried to make systems that worked the way the researchers thought their own minds worked---they tried to put that knowledge in their systems---but it proved ultimately counterproductive, and a colossal waste of researcher's time, when, through Moore's law, massive computation became available and a means was found to put it to good use.", metadata={'page_content': "In speech recognition, there was an early competition, sponsored by DARPA, in the 1970s. Entrants included a host of special methods that took advantage of human knowledge---knowledge of words, of phonemes, of the human vocal tract, etc. On the other side were newer methods that were more statistical in nature and did much more computation, based on hidden Markov models (HMMs). Again, the statistical methods won out over the human-knowledge-based methods. This led to a major change in all of natural language processing, gradually over decades, where statistics and computation came to dominate the field. The recent rise of deep learning in speech recognition is the most recent step in this consistent direction. Deep learning methods rely even less on human knowledge, and use even more computation, together with learning on huge training sets, to produce dramatically better speech recognition systems. As in the games, researchers always tried to make systems that worked the way the researchers thought their own minds worked---they tried to put that knowledge in their systems---but it proved ultimately counterproductive, and a colossal waste of researcher's time, when, through Moore's law, massive computation became available and a means was found to put it to good use.", 'type': 'Document', 'id': 'a843ad30894ac7b02e9766aa364f5d1ce8812c7a123fe1c47be921a8bccbdb78'}),
#   Document(page_content='In computer vision, there has been a similar pattern. Early methods conceived of vision as searching for edges, or generalized cylinders, or in terms of SIFT features. But today all this is discarded. Modern deep-learning neural networks use only the notions of convolution and certain kinds of invariances, and perform much better.', metadata={'page_content': 'In computer vision, there has been a similar pattern. Early methods conceived of vision as searching for edges, or generalized cylinders, or in terms of SIFT features. But today all this is discarded. Modern deep-learning neural networks use only the notions of convolution and certain kinds of invariances, and perform much better.', 'type': 'Document', 'id': '81b1e10e34c5ad14eb3d486e5bcd1fd5b204bdf1536926682e462b913e18eba1'}),
#   Document(page_content='This is a big lesson. As a field, we still have not thoroughly learned it, as we are continuing to make the same kind of mistakes. To see this, and to effectively resist it, we have to understand the appeal of these mistakes. We have to learn the bitter lesson that building in how we think we think does not work in the long run. The bitter lesson is based on the historical observations that 1) AI researchers have often tried to build knowledge into their agents, 2) this always helps in the short term, and is personally satisfying to the researcher, but 3) in the long run it plateaus and even inhibits further progress, and 4) breakthrough progress eventually arrives by an opposing approach based on scaling computation by search and learning. The eventual success is tinged with bitterness, and often incompletely digested, because it is success over a favored, human-centric approach.', metadata={'page_content': 'This is a big lesson. As a field, we still have not thoroughly learned it, as we are continuing to make the same kind of mistakes. To see this, and to effectively resist it, we have to understand the appeal of these mistakes. We have to learn the bitter lesson that building in how we think we think does not work in the long run. The bitter lesson is based on the historical observations that 1) AI researchers have often tried to build knowledge into their agents, 2) this always helps in the short term, and is personally satisfying to the researcher, but 3) in the long run it plateaus and even inhibits further progress, and 4) breakthrough progress eventually arrives by an opposing approach based on scaling computation by search and learning. The eventual success is tinged with bitterness, and often incompletely digested, because it is success over a favored, human-centric approach.', 'type': 'Document', 'id': 'f594c4973b093dc0408a3057bbcf876f1d746adeaedc97ac284691bc3be18924'}),
#   Document(page_content='One thing that should be learned from the bitter lesson is the great power of general purpose methods, of methods that continue to scale with increased computation even as the available computation becomes very great. The two methods that seem to scale arbitrarily in this way are search and learning.', metadata={'page_content': 'One thing that should be learned from the bitter lesson is the great power of general purpose methods, of methods that continue to scale with increased computation even as the available computation becomes very great. The two methods that seem to scale arbitrarily in this way are search and learning.', 'type': 'Document', 'id': '82b21c6194d958e6c5b1bbd066b0a9d06a5f91b542279238a5f8200b656fda50'}),
#   Document(page_content='The second general point to be learned from the bitter lesson is that the actual contents of minds are tremendously, irredeemably complex; we should stop trying to find simple ways to think about the contents of minds, such as simple ways to think about space, objects, multiple agents, or symmetries. All these are part of the arbitrary, intrinsically-complex, outside world. They are not what should be built in, as their complexity is endless; instead we should build in only the meta-methods that can find and capture this arbitrary complexity. Essential to these methods is that they can find good approximations, but the search for them should be by our methods, not by us. We want AI agents that can discover like we can, not which contain what we have discovered. Building in our discoveries only makes it harder to see how the discovering process can be done.', metadata={'page_content': 'The second general point to be learned from the bitter lesson is that the actual contents of minds are tremendously, irredeemably complex; we should stop trying to find simple ways to think about the contents of minds, such as simple ways to think about space, objects, multiple agents, or symmetries. All these are part of the arbitrary, intrinsically-complex, outside world. They are not what should be built in, as their complexity is endless; instead we should build in only the meta-methods that can find and capture this arbitrary complexity. Essential to these methods is that they can find good approximations, but the search for them should be by our methods, not by us. We want AI agents that can discover like we can, not which contain what we have discovered. Building in our discoveries only makes it harder to see how the discovering process can be done.', 'type': 'Document', 'id': '85e9852c038095c56b97f854ff140c6404183463d8131185157c342c5b731f59'})],
#  'relations': [[Relation(node_1=Node(id='35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3', name='AI Research', type='Node', metadata={}), edge=Edge(id='4937ca29d5c3c3189e0dc6cd8fa1f2eca307f114f08e9046429162a119860ed2', name='Conducted With Limited Computation', type='Edge', metadata={}), node_2=Node(id='5a9ff1e640294c3ae5f3f2b69516a6c2af5776f5e3e262e04be2055925ab9ef8', name='Constant Computation', type='Node', metadata={})),
#    Relation(node_1=Node(id='64a33131405f0d22dcafa90df969d1c23abddc10ce9755b3dd5ded1d039116ce', name="Moore's Law", type='Node', metadata={}), edge=Edge(id='c6285a0fb648155a4b1ba053cce987d662a91d06a27f900f35cf7758ef499849', name='Generalizes Falling Cost Per Unit Of Computation', type='Edge', metadata={}), node_2=Node(id='02df1f506ee2be9a234c62f3a2828edd542792ee67d0789468cf72641c5b75aa', name='Exponentially Falling Cost Per Unit Of Computation', type='Node', metadata={})),
#    Relation(node_1=Node(id='63158218a6b8ea29bfb465c263af15671f8198e16bb1605370e9480ea43e8f08', name='Human Knowledge', type='Node', metadata={}), edge=Edge(id='999aa24bc012ca8a57b6b03951b2b6ec8c327a43e46b13e6dad8bc9a869a28b5', name='Leveraged In AI Research', type='Edge', metadata={}), node_2=Node(id='35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3', name='AI Research', type='Node', metadata={})),
#    Relation(node_1=Node(id='e72390b4f750cabf73d01f0e3d5099731cdea87dba977a74d6848296a89ed0a1', name='Computation', type='Node', metadata={}), edge=Edge(id='93382f88383916c2fae43ac53b139d2d268d71cd356806b296d0ff9c48eced7b', name='Leveraged In AI Research', type='Edge', metadata={}), node_2=Node(id='35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3', name='AI Research', type='Node', metadata={})),
#    Relation(node_1=Node(id='2bdd57ea2d33b1dce344a8c019e8d45a2072e8587db0b33bc131e2e56803e45e', name='Human-Knowledge Approach', type='Node', metadata={}), edge=Edge(id='80f1a56188159f3b3950993e8bd6a9fc93cf920e19db2b9cd0ec73b8631dccf3', name='Complicates Methods', type='Edge', metadata={}), node_2=Node(id='1bec1585df1faa6c236384b39b104b732aec6e18567fe4ee8242e8ae4a66e60e', name='General Methods', type='Node', metadata={})),
#    Relation(node_1=Node(id='1bec1585df1faa6c236384b39b104b732aec6e18567fe4ee8242e8ae4a66e60e', name='General Methods', type='Node', metadata={}), edge=Edge(id='4cfece46aede5df40697ea9a254ba91b660eb04e5f57e96162d7d2c270ddd180', name='Leverage Computation', type='Edge', metadata={}), node_2=Node(id='e72390b4f750cabf73d01f0e3d5099731cdea87dba977a74d6848296a89ed0a1', name='Computation', type='Node', metadata={})),
#    Relation(node_1=Node(id='33b93476cf597a3330653b66a658983d892ac264b5d6029a2dc642b9b1f30870', name='Time', type='Node', metadata={}), edge=Edge(id='c1e6bc6da6844ddbd52416551fc481164a7905da3958ba8f7c546183ef221691', name='Spent On Human Knowledge Or Computation', type='Edge', metadata={}), node_2=Node(id='e55c3786db8c0641fbd41d3a896ca81df2e203152636d80cd3b7df26ecc53670', name='Human Knowledge Or Computation', type='Node', metadata={})),
#    Relation(node_1=Node(id='e26fa728dba3d94f9884b00bdfb153f06687d9de40950272cc286e8384632f32', name='Psychological Commitments', type='Node', metadata={}), edge=Edge(id='3156594d7d2609b1c4f900e6e4695aae80b59bccdf12811736a7205f5be29084', name='Invested In Human Knowledge Or Computation', type='Edge', metadata={}), node_2=Node(id='e55c3786db8c0641fbd41d3a896ca81df2e203152636d80cd3b7df26ecc53670', name='Human Knowledge Or Computation', type='Node', metadata={}))],
#   [Relation(node_1=Node(id='c52e9d0a2bbc615c4aed1d4b33752d16f986db417355e62b176c6398df32f7f2', name='Computer Chess', type='Node', metadata={}), edge=Edge(id='3e88a32bfb7ff9e4765bcdf30b8ed0ce1b019842f043de8f0275db99d6d346cb', name='Uses', type='Edge', metadata={}), node_2=Node(id='473c5aa541f906634d46163d3bba205d52d42e44d20817a5af9b7470d92ffb06', name='Search-Based Approach', type='Node', metadata={})),
#    Relation(node_1=Node(id='3cca9b91d3b8ee06560808339e59fe6f253ed8fe69fbd541c7cb566b75c82d04', name='Kasparov', type='Node', metadata={}), edge=Edge(id='b8ca392dd521beee7197a8aaabc583eea79e1567bb8ef9f95e04c013ef292f27', name='Was Defeated By', type='Edge', metadata={}), node_2=Node(id='473c5aa541f906634d46163d3bba205d52d42e44d20817a5af9b7470d92ffb06', name='Search-Based Approach', type='Node', metadata={})),
#    Relation(node_1=Node(id='7d10850cfeb3225363c3f41fb21c1e40bf050a8fa808c1c13790d5f482b73346', name='Computer-Chess Researchers', type='Node', metadata={}), edge=Edge(id='848328a8a34dc48e711109db08fb23796e4e82f3e843204661beb1a711c4a9c8', name='Pursued', type='Edge', metadata={}), node_2=Node(id='7b4869ef463fd039111b7f68db809fdd84e1ee66bf364139c0b2fb065120c1e1', name='Human Understanding', type='Node', metadata={})),
#    Relation(node_1=Node(id='7b4869ef463fd039111b7f68db809fdd84e1ee66bf364139c0b2fb065120c1e1', name='Human Understanding', type='Node', metadata={}), edge=Edge(id='7056040c776162fd48b9fc891050f88fe764d293c8535a6cb6490957a58eebae', name='Of', type='Edge', metadata={}), node_2=Node(id='ce2970bcbb34ea9dc1899a0aa6eec0cff1f3206c0917c4dad793274a3bfe64d4', name='Special Structure Of Chess', type='Node', metadata={})),
#    Relation(node_1=Node(id='473c5aa541f906634d46163d3bba205d52d42e44d20817a5af9b7470d92ffb06', name='Search-Based Approach', type='Node', metadata={}), edge=Edge(id='0c1ec6d58d7db4876bc145f2ec2bc45730b6517342b77c68b5c628b4eb892d8b', name='Uses', type='Edge', metadata={}), node_2=Node(id='0340f3eef10be4f7b8de9e3673dde9b7f26d8757a3cf9372c87eeaa9ab173ed4', name='Special Hardware And Software', type='Node', metadata={})),
#    Relation(node_1=Node(id='7d10850cfeb3225363c3f41fb21c1e40bf050a8fa808c1c13790d5f482b73346', name='Computer-Chess Researchers', type='Node', metadata={}), edge=Edge(id='a96b1b9c9f56842c8ff87dbc876912ad6ea132c343a8cdf92f4e3baf009782af', name='Were Disappointed By', type='Edge', metadata={}), node_2=Node(id='473c5aa541f906634d46163d3bba205d52d42e44d20817a5af9b7470d92ffb06', name='Search-Based Approach', type='Node', metadata={})),
#    Relation(node_1=Node(id='7d10850cfeb3225363c3f41fb21c1e40bf050a8fa808c1c13790d5f482b73346', name='Computer-Chess Researchers', type='Node', metadata={}), edge=Edge(id='22a7390dd2a8130fc85f751269bf79f5eef9f82b744e034603e30b66b5d8f4b7', name='Wanted To Win With', type='Edge', metadata={}), node_2=Node(id='33cb27cff9eb9f824cbd6dbb7e917f8de2e3bda67eaae87abbc97946fd43717f', name='Methods Based On Human Input', type='Node', metadata={}))],
#   [Relation(node_1=Node(id='67772e38784f9bd8a66a5b126169d6c02a7f612d3b25d0d45d68ecde6578bc36', name='Computer Go', type='Node', metadata={}), edge=Edge(id='214a1bef1dad0f48b6eddd1a0d3cbc0bd12874e4a568fc0e3b49de0b3f1db032', name='Is A Type Of', type='Edge', metadata={}), node_2=Node(id='5c412a262086b9701cda06302f6667f9265b1807d0368fcec6cc03bf64fc250b', name='Game', type='Node', metadata={})),
#    Relation(node_1=Node(id='49c266baaaa70981ea188fa714d5c40cf13830d786a861c9943ae0d26a7f3fe9', name='Search', type='Node', metadata={}), edge=Edge(id='ff0e00ff5b0e79f2298b999b97737761c58d4308298debc3386a9299f128ca61', name='Enables', type='Edge', metadata={}), node_2=Node(id='ed679e9795201dcb9f27cc3845abc56c766b7049ed536019fb9189bc7dbb3c44', name='Massive Computation', type='Node', metadata={})),
#    Relation(node_1=Node(id='8b45bb20e0775c30641210abeddb520ac385ae05e90bd6cbdcd8304a39f04623', name='Learning', type='Node', metadata={}), edge=Edge(id='f48ab8c11b96bb8707cc3585353fbb9dcf75ccb059b35d85ef7fcfd0ca5a3ca4', name='Enables', type='Edge', metadata={}), node_2=Node(id='ed679e9795201dcb9f27cc3845abc56c766b7049ed536019fb9189bc7dbb3c44', name='Massive Computation', type='Node', metadata={})),
#    Relation(node_1=Node(id='49c266baaaa70981ea188fa714d5c40cf13830d786a861c9943ae0d26a7f3fe9', name='Search', type='Node', metadata={}), edge=Edge(id='f2b69a2dc0754d58c5e48072c310bc9d324f8f5e53f144eb44fdf38208ab2c40', name='Is A Type Of', type='Edge', metadata={}), node_2=Node(id='bf4043a9b3dff077edfe02f1f6addb18d8e03e9a73c4c04bd4579deeef375b77', name='Technique', type='Node', metadata={})),
#    Relation(node_1=Node(id='8b45bb20e0775c30641210abeddb520ac385ae05e90bd6cbdcd8304a39f04623', name='Learning', type='Node', metadata={}), edge=Edge(id='1c8e72199217686e09f4cb7350b045b988b65a244b9fe0cc41d1d26c831f8583', name='Is A Type Of', type='Edge', metadata={}), node_2=Node(id='bf4043a9b3dff077edfe02f1f6addb18d8e03e9a73c4c04bd4579deeef375b77', name='Technique', type='Node', metadata={})),
#    Relation(node_1=Node(id='c52e9d0a2bbc615c4aed1d4b33752d16f986db417355e62b176c6398df32f7f2', name='Computer Chess', type='Node', metadata={}), edge=Edge(id='f0dadc427bb2d5d84da87718bbff53e3449521a8682097d6a32602337de3c2f7', name='Is Similar To', type='Edge', metadata={}), node_2=Node(id='67772e38784f9bd8a66a5b126169d6c02a7f612d3b25d0d45d68ecde6578bc36', name='Computer Go', type='Node', metadata={})),
#    Relation(node_1=Node(id='63158218a6b8ea29bfb465c263af15671f8198e16bb1605370e9480ea43e8f08', name='Human Knowledge', type='Node', metadata={}), edge=Edge(id='e0fa97624c84ebfd8a803c8387bc3fc43c69865d30c2fdf198e6a4c146e69358', name='Was Utilized In', type='Edge', metadata={}), node_2=Node(id='67772e38784f9bd8a66a5b126169d6c02a7f612d3b25d0d45d68ecde6578bc36', name='Computer Go', type='Node', metadata={})),
#    Relation(node_1=Node(id='227c90dbfaf57750ab06c86159973993129158fbdc1ee7916004555fde242a63', name='Self Play', type='Node', metadata={}), edge=Edge(id='6f1b35fe6b83b2ee56ec6e6ac3808df93ac74463134837b64f4d52dfd4dea764', name='Is A Type Of', type='Edge', metadata={}), node_2=Node(id='8b45bb20e0775c30641210abeddb520ac385ae05e90bd6cbdcd8304a39f04623', name='Learning', type='Node', metadata={})),
#    Relation(node_1=Node(id='86bc0c7e79a086ab0977d41c113d883e149adb38dcc6d886472cf32076e17a94', name='Value Function', type='Node', metadata={}), edge=Edge(id='15cc110282909724df212bdbcfd4b799957a660fc6e47c9bf5f4477de2d491ee', name='Is Learned Through', type='Edge', metadata={}), node_2=Node(id='227c90dbfaf57750ab06c86159973993129158fbdc1ee7916004555fde242a63', name='Self Play', type='Node', metadata={}))],
#   [Relation(node_1=Node(id='90da48068c880fee021dc6197aa8c1a2bd22eb8451c316d293ed63777a136c25', name='Speech Recognition', type='Node', metadata={}), edge=Edge(id='d73bb5bbfb53d8a5ccf296e854cdaf2ba02f2a4c14d80ab1fe39e0cb8e37710c', name='Is A Field Of', type='Edge', metadata={}), node_2=Node(id='b11715562f26ff15acd462701d4a427dbaae610f687fbdd3530581892ec5e1ac', name='Natural Language Processing', type='Node', metadata={})),
#    Relation(node_1=Node(id='972a2890cb0bce38594f4c0a4a1fb2911bcc48e233219a3237112533b576a5c2', name='DARPA', type='Node', metadata={}), edge=Edge(id='aeba4acfcf61d81a1b70dc3eac95f27ac3c4d2a495c85beeed375009b26bed76', name='Sponsored', type='Edge', metadata={}), node_2=Node(id='449303332f88997ae6389add7de42f361aa69068157b81b78327e111fc7f63b0', name='Competition', type='Node', metadata={})),
#    Relation(node_1=Node(id='63158218a6b8ea29bfb465c263af15671f8198e16bb1605370e9480ea43e8f08', name='Human Knowledge', type='Node', metadata={}), edge=Edge(id='f55c80b7554e9d157110e2438722ae5119b196deec612885d1a9a141988ad3df', name='Was Used In', type='Edge', metadata={}), node_2=Node(id='7994bf4fc3d7915ab55cd900620afab00c5e6c9c7ab8d4044b2259d89330dfa9', name='Early Methods', type='Node', metadata={})),
#    Relation(node_1=Node(id='a9856d4e2dcffbcee88eb3d737ff06cbd6344c8ceaa45802ec9fe51d5e3002cb', name='Statistical Methods', type='Node', metadata={}), edge=Edge(id='71d67e4bb298fcfd2acfe5cd190c4abe59d8c5f9cd38981bac0a72cb5b07c779', name='Won Over', type='Edge', metadata={}), node_2=Node(id='d27cfe5beb29ee5cb73dca63695d816affe662756beba38f859c64c5bbaee025', name='Human-Knowledge-Based Methods', type='Node', metadata={})),
#    Relation(node_1=Node(id='0a92c85fdb29d7d54a4a6a346c01b7a7b519c7cc2bb91843a1b5e841fe6caf7a', name='Hidden Markov Models (HMMs)', type='Node', metadata={}), edge=Edge(id='f55ca8a28cc0617fb03d53ba89ec1e01dbf32b5ba6239bffd117c56e1dfa6161', name='Is A Type Of', type='Edge', metadata={}), node_2=Node(id='a9856d4e2dcffbcee88eb3d737ff06cbd6344c8ceaa45802ec9fe51d5e3002cb', name='Statistical Methods', type='Node', metadata={})),
#    Relation(node_1=Node(id='bcd41373249e305015545f00cf618a7d2d225e4368f8b360d753e469570e59a4', name='Deep Learning', type='Node', metadata={}), edge=Edge(id='3f67b930906bd4a81b9e6b89a60f11be167729b0dfaf11c1dfe2cdba0c2136d5', name='Is A Type Of', type='Edge', metadata={}), node_2=Node(id='a9856d4e2dcffbcee88eb3d737ff06cbd6344c8ceaa45802ec9fe51d5e3002cb', name='Statistical Methods', type='Node', metadata={})),
#    Relation(node_1=Node(id='bcd41373249e305015545f00cf618a7d2d225e4368f8b360d753e469570e59a4', name='Deep Learning', type='Node', metadata={}), edge=Edge(id='c1b84e11e341ddc35055033a4078d1d9d6d57308aaac5116e51fd8a31ae61afe', name='Uses', type='Edge', metadata={}), node_2=Node(id='aa1f17247d87bd510910e0655f6db47d0a85e3403376b284042371c554269743', name='Huge Training Sets', type='Node', metadata={})),
#    Relation(node_1=Node(id='de7757d95832f91a8e8a071d3012d6bb8d6cfb7fd1a8aef974c599cf4bcf94f3', name='Researchers', type='Node', metadata={}), edge=Edge(id='2c07cb2d4d607b69c876bcc14d2b00e217d0e296adb457b59370cbde5b3fac28', name='Tried To Make Systems Based On', type='Edge', metadata={}), node_2=Node(id='daf0b5c4561878fa9bb176edb5c80dfd3cd555f777e95812a724cd2aab34d743', name='Their Own Minds', type='Node', metadata={})),
#    Relation(node_1=Node(id='64a33131405f0d22dcafa90df969d1c23abddc10ce9755b3dd5ded1d039116ce', name="Moore's Law", type='Node', metadata={}), edge=Edge(id='92b486624ddf9addea2db045a21b71a3a946c4afb8991255050c60417944a721', name='Enabled', type='Edge', metadata={}), node_2=Node(id='ed679e9795201dcb9f27cc3845abc56c766b7049ed536019fb9189bc7dbb3c44', name='Massive Computation', type='Node', metadata={}))],
#   [Relation(node_1=Node(id='69dbf44b3d90e7faf94f5813c530bc1d12f22e773ce4e901c33a159c8682edfb', name='Computer Vision', type='Node', metadata={}), edge=Edge(id='8cdd48d30927eeb7226533d5d646529a4baf7b923c4e3f5ba4d4400e5629674e', name='Has Pattern', type='Edge', metadata={}), node_2=Node(id='7994bf4fc3d7915ab55cd900620afab00c5e6c9c7ab8d4044b2259d89330dfa9', name='Early Methods', type='Node', metadata={})),
#    Relation(node_1=Node(id='7994bf4fc3d7915ab55cd900620afab00c5e6c9c7ab8d4044b2259d89330dfa9', name='Early Methods', type='Node', metadata={}), edge=Edge(id='bd5aa63f60e361fd0ae5c2e56541fd79d25bc6847aab8e034a856befc769d50e', name='Conceived Of', type='Edge', metadata={}), node_2=Node(id='658b158af9bde570fd7936f48d14af314d7a400afbc3a377157379b0eb6e6f41', name='Edges', type='Node', metadata={})),
#    Relation(node_1=Node(id='7994bf4fc3d7915ab55cd900620afab00c5e6c9c7ab8d4044b2259d89330dfa9', name='Early Methods', type='Node', metadata={}), edge=Edge(id='b7bcd621a0ff165cf20a2adaac7e0320419b85b1582e2770f660fef859ec1cfc', name='Conceived Of', type='Edge', metadata={}), node_2=Node(id='5dabf2b6f1cff85dd81fb39c04ffc9b3d0266fd9b24efc850c78ed60453dc01b', name='Generalized Cylinders', type='Node', metadata={})),
#    Relation(node_1=Node(id='7994bf4fc3d7915ab55cd900620afab00c5e6c9c7ab8d4044b2259d89330dfa9', name='Early Methods', type='Node', metadata={}), edge=Edge(id='2b2d259b8264a4699569afbb623a48b8affe7b617aa52deb10c082a5c52932e8', name='Conceived Of', type='Edge', metadata={}), node_2=Node(id='366e2ba7064d699996a59c8d156e4234b5e843722b3a55d406ae93afbc230e3c', name='SIFT Features', type='Node', metadata={})),
#    Relation(node_1=Node(id='01f3cb9b857e57e70ffeee91cc3151f504afa2f11d43f531f65fe183877e0a14', name='Modern Deep-Learning Neural Networks', type='Node', metadata={}), edge=Edge(id='08043e32b5c2701f98c45ae1f6e6a32913c7800ea082d487326d21d93722c998', name='Use', type='Edge', metadata={}), node_2=Node(id='abe1467b3976874f6a3ba0549d13090f903f0a247b6fbfbe977cb1771d9e94b3', name='Convolution', type='Node', metadata={})),
#    Relation(node_1=Node(id='01f3cb9b857e57e70ffeee91cc3151f504afa2f11d43f531f65fe183877e0a14', name='Modern Deep-Learning Neural Networks', type='Node', metadata={}), edge=Edge(id='f3d282e1c53a74394142e1ad3b148e04cb7e319a1d6aabaed9ff3a746b287343', name='Use', type='Edge', metadata={}), node_2=Node(id='6c0df0615a7396aff6760d8084829fc01e72167da0bc43740e19bacfed2070ae', name='Invariances', type='Node', metadata={})),
#    Relation(node_1=Node(id='01f3cb9b857e57e70ffeee91cc3151f504afa2f11d43f531f65fe183877e0a14', name='Modern Deep-Learning Neural Networks', type='Node', metadata={}), edge=Edge(id='a15f1378e24da37b514e1d75abd184006ab2ac2e054e89b7cfd264e291cbbb81', name='Perform', type='Edge', metadata={}), node_2=Node(id='7bf8c23d17f1f1c0fdfb1e797057acb4bde3d9096d9830be47647a708b0371f9', name='Better', type='Node', metadata={}))],
#   [Relation(node_1=Node(id='45e8f94ceacdcb34438a89cbb5335f6a54114f27c9f5da64545e486f6cf29107', name='AI Researchers', type='Node', metadata={}), edge=Edge(id='44e31bfd82dbcfa8121f79e84d512865fd3841e224dcc17f0bef0945e2068504', name='Make Mistakes', type='Edge', metadata={}), node_2=Node(id='0079708aa0a9898ab401a6c185feb939412b4e89b907ae750c066dab21d0c1be', name='Mistakes', type='Node', metadata={})),
#    Relation(node_1=Node(id='0079708aa0a9898ab401a6c185feb939412b4e89b907ae750c066dab21d0c1be', name='Mistakes', type='Node', metadata={}), edge=Edge(id='49c27712a442b8a1d623ad351cc90113832f4edc4e50ef89e98eed21b18e652f', name='Are Based On', type='Edge', metadata={}), node_2=Node(id='66db69754708ee9d0790803023245758a770ff4546e0019c0ac8e89077ad4482', name='Building In How We Think', type='Node', metadata={})),
#    Relation(node_1=Node(id='66db69754708ee9d0790803023245758a770ff4546e0019c0ac8e89077ad4482', name='Building In How We Think', type='Node', metadata={}), edge=Edge(id='67c0db5a8ce92f6cc72421e9d4730a17abec52409adb51964ceb223dde6c364e', name='Does Not Work In', type='Edge', metadata={}), node_2=Node(id='927b64da2153885af7c982c75fc912cda8d1c66a128d98d41c1f3f475eda2034', name='The Long Run', type='Node', metadata={})),
#    Relation(node_1=Node(id='f6f2d05604d37d2c43ff0e6fb88d63541ee666996ff7a81e6c575b4ebc77d622', name='The Bitter Lesson', type='Node', metadata={}), edge=Edge(id='5ec2ff2ea47d80668927f3decebb36499c090447a302485046a03ae7f4018ce0', name='Is Based On', type='Edge', metadata={}), node_2=Node(id='907406fc16d789182e1d9300507accff692c0b8f65c281f4594db3e57892b4ea', name='Historical Observations', type='Node', metadata={})),
#    Relation(node_1=Node(id='907406fc16d789182e1d9300507accff692c0b8f65c281f4594db3e57892b4ea', name='Historical Observations', type='Node', metadata={}), edge=Edge(id='b8f12702a9221357bc0ab207069003f880fe1dd0a4c799813a5d669931578533', name='Include', type='Edge', metadata={}), node_2=Node(id='1cc707d5a536a48e111f90fce5886a7998ed2771066296bd8e9e36421b4fd78f', name='AI Researchers Trying To Build Knowledge', type='Node', metadata={})),
#    Relation(node_1=Node(id='1cc707d5a536a48e111f90fce5886a7998ed2771066296bd8e9e36421b4fd78f', name='AI Researchers Trying To Build Knowledge', type='Node', metadata={}), edge=Edge(id='4b5fe1d21f70021f7cbbf26aac99122ee20dfc83bb2a2dbda9eb98b449a06d43', name='Helps In', type='Edge', metadata={}), node_2=Node(id='6a674ae81d3723232d0356de59917f98bcf2772d6ee32a63f33f3c49dcdca9cb', name='The Short Term', type='Node', metadata={})),
#    Relation(node_1=Node(id='6a674ae81d3723232d0356de59917f98bcf2772d6ee32a63f33f3c49dcdca9cb', name='The Short Term', type='Node', metadata={}), edge=Edge(id='5bb11169ef65f1c2b2d9ca501f02dd5a17170d535ca3fb5baf0c627e16ddea74', name='Is Personally Satisfying To', type='Edge', metadata={}), node_2=Node(id='7b596ed45535e19619a004bf8f1cc0fcb4afbbeeb6492fc862362c75446adf4d', name='The Researcher', type='Node', metadata={})),
#    Relation(node_1=Node(id='927b64da2153885af7c982c75fc912cda8d1c66a128d98d41c1f3f475eda2034', name='The Long Run', type='Node', metadata={}), edge=Edge(id='c0ee41f29a14474d3cd86be6ae3d2e4bff1016b5e2ce76a0a60cfc4fab770656', name='Plateaus And Inhibits', type='Edge', metadata={}), node_2=Node(id='d22df8d1aa1ed5bf5aa9fb5931ca835cc5993c70e97e67e8514f604e560b1959', name='Further Progress', type='Node', metadata={})),
#    Relation(node_1=Node(id='7b0444c37d7d3d4f8ab07b051ae3dbf4352383dfc12c936956d5a5283ba4ed0f', name='Breakthrough Progress', type='Node', metadata={}), edge=Edge(id='cca4669f4641dd2b1c86a69fba782f7a47196c073586076f94c49ccc2a3ec57a', name='Arrives By', type='Edge', metadata={}), node_2=Node(id='1057f2958ea0c03d4bb8a5a2ff6d58e104f755f8f169817e5615a1afb6b7293d', name='Scaling Computation By Search And Learning', type='Node', metadata={})),
#    Relation(node_1=Node(id='7b0444c37d7d3d4f8ab07b051ae3dbf4352383dfc12c936956d5a5283ba4ed0f', name='Breakthrough Progress', type='Node', metadata={}), edge=Edge(id='b5d4971049eb833d73c99ac215968f2ceeb76b3c8efcb7328bc8dee4938db2f5', name='Is Tinged With', type='Edge', metadata={}), node_2=Node(id='d36a54f38be4081b5d3c377245508d0e5537315be14920e4537362f567e3fb15', name='Bitterness', type='Node', metadata={})),
#    Relation(node_1=Node(id='d36a54f38be4081b5d3c377245508d0e5537315be14920e4537362f567e3fb15', name='Bitterness', type='Node', metadata={}), edge=Edge(id='98cf7327ebda7749594efe9cab6d90bc1fd51b7b84c7eeaf97d0788cab52b637', name='Is Due To', type='Edge', metadata={}), node_2=Node(id='84a115de575bd8bcc71b81c4e51289af1ccd8f4eea787b663915eae554c7f9be', name='Success Over A Favored Approach', type='Node', metadata={}))],
#   [Relation(node_1=Node(id='6797d13360a73f5a63e4b0bee9bf37c20cb43382b4850e84e02ef69c01a2f853', name='General Purpose Methods', type='Node', metadata={}), edge=Edge(id='8f627ab1d961f8b997493f82c40f45c041bbc46b6b05d50cb92edd4d506b92fb', name='Are Characterized By', type='Edge', metadata={}), node_2=Node(id='814fe33f11b361fc73ff4f675dbc995a882dc7397d550f2f5a91bcfe72fbe57d', name='Scalability', type='Node', metadata={})),
#    Relation(node_1=Node(id='49c266baaaa70981ea188fa714d5c40cf13830d786a861c9943ae0d26a7f3fe9', name='Search', type='Node', metadata={}), edge=Edge(id='e261cc635a54c9f27e7a952a2e3ea2b6b243c9ee71e48780f5f711a7617c24bc', name='Is A Type Of', type='Edge', metadata={}), node_2=Node(id='6797d13360a73f5a63e4b0bee9bf37c20cb43382b4850e84e02ef69c01a2f853', name='General Purpose Methods', type='Node', metadata={})),
#    Relation(node_1=Node(id='8b45bb20e0775c30641210abeddb520ac385ae05e90bd6cbdcd8304a39f04623', name='Learning', type='Node', metadata={}), edge=Edge(id='2be76ccd2d72700d6641be14e1416b10e71ba6207d6a610da7d35a22f18b0b14', name='Is A Type Of', type='Edge', metadata={}), node_2=Node(id='6797d13360a73f5a63e4b0bee9bf37c20cb43382b4850e84e02ef69c01a2f853', name='General Purpose Methods', type='Node', metadata={})),
#    Relation(node_1=Node(id='e72390b4f750cabf73d01f0e3d5099731cdea87dba977a74d6848296a89ed0a1', name='Computation', type='Node', metadata={}), edge=Edge(id='aff66567f79ee459ac6cb83662633c11e35059e5f84a0a0b8dbbf5f882efb287', name='Increases', type='Edge', metadata={}), node_2=Node(id='814fe33f11b361fc73ff4f675dbc995a882dc7397d550f2f5a91bcfe72fbe57d', name='Scalability', type='Node', metadata={}))],
#   [Relation(node_1=Node(id='8dbf45f04541c2a50495e19689fcd7956c7771220ae3c9cab8f225b435533d1f', name='Minds', type='Node', metadata={}), edge=Edge(id='d4bf6874fe54d900746966d64d037130ce9ab04d5433495bd0126e3f792191ae', name='Have Complex Contents', type='Edge', metadata={}), node_2=Node(id='2dcf78dcabca38ef0498d4e991bda2c39f8445f5b1db2f89c87759f713f2e42e', name='Complexity', type='Node', metadata={})),
#    Relation(node_1=Node(id='20eac5aae274985fd88629d19eddccbbec21dacd82a8c7a7dd99661f2135be02', name='Space', type='Node', metadata={}), edge=Edge(id='d41a709526deed4b620b50e0f911ae6b139e52ad4616b799191a968ccb51ecaf', name='Is Part Of', type='Edge', metadata={}), node_2=Node(id='84ac18b92d336b1cffa3a49acfd2f73c3d4f441417f5c4658776c0e22948f92e', name='Outside World', type='Node', metadata={})),
#    Relation(node_1=Node(id='de5236ee1561d9d4123d1a8dad5442710ac2acdc26111be2076d9b8ddf453650', name='Objects', type='Node', metadata={}), edge=Edge(id='e4b724a96340b0340faaedb8f194ceda8ddad018164d1f2c7cc850f66622277f', name='Are Part Of', type='Edge', metadata={}), node_2=Node(id='84ac18b92d336b1cffa3a49acfd2f73c3d4f441417f5c4658776c0e22948f92e', name='Outside World', type='Node', metadata={})),
#    Relation(node_1=Node(id='f5df9e6273b86a1b7a08ea02a149d4caf05615451204495ac2f1454dcd4c2a52', name='Multiple Agents', type='Node', metadata={}), edge=Edge(id='2622e5837ea5b25b460f16bfa15e054001532bcbd1d0a43836251ea6bd262077', name='Are Part Of', type='Edge', metadata={}), node_2=Node(id='84ac18b92d336b1cffa3a49acfd2f73c3d4f441417f5c4658776c0e22948f92e', name='Outside World', type='Node', metadata={})),
#    Relation(node_1=Node(id='9b4a1aebdb63e12e672126bf9de18d3106507f61edf36227d4e1c2403f07893d', name='Symmetries', type='Node', metadata={}), edge=Edge(id='7c757fdf58dd8d56324c9d54b661a2ae2b2907fd3f27db67cd30c6a94df47068', name='Are Part Of', type='Edge', metadata={}), node_2=Node(id='84ac18b92d336b1cffa3a49acfd2f73c3d4f441417f5c4658776c0e22948f92e', name='Outside World', type='Node', metadata={})),
#    Relation(node_1=Node(id='a571112dd1b9e6b6dc4879bbb945ed7e5996c7805b80a5095d9442b209a222fe', name='Meta-Methods', type='Node', metadata={}), edge=Edge(id='fc5c19231ee9898ecd4d5797ecf7e5142f0aec0aaadf53d4717fae8e5911e13e', name='Can Find', type='Edge', metadata={}), node_2=Node(id='2dcf78dcabca38ef0498d4e991bda2c39f8445f5b1db2f89c87759f713f2e42e', name='Complexity', type='Node', metadata={})),
#    Relation(node_1=Node(id='d591a7cb7e700672a854ef44e0ec7bfa06cdddaa3f5b530240ec9596cf15d241', name='AI Agents', type='Node', metadata={}), edge=Edge(id='7dd1c5b195ae33c976472d50d4ad48a644160413aa762a23f11dd77ab60a332d', name='Should Discover', type='Edge', metadata={}), node_2=Node(id='2dcf78dcabca38ef0498d4e991bda2c39f8445f5b1db2f89c87759f713f2e42e', name='Complexity', type='Node', metadata={})),
#    Relation(node_1=Node(id='df153402cb2f2be9b2b84a59cc11b30882cac5952758abbe42278d3429366707', name='Discovering Process', type='Node', metadata={}), edge=Edge(id='906452ab33898e650be71008851d6b1caa2836cbe9535e7ffe1947e9e871c716', name='Is Done By', type='Edge', metadata={}), node_2=Node(id='a571112dd1b9e6b6dc4879bbb945ed7e5996c7805b80a5095d9442b209a222fe', name='Meta-Methods', type='Node', metadata={}))]]}

# %%
nodes = graph.similarity_search("ai", doc_type='node')
nodes
# Out:
# ['AI Research',
#  'Space',
#  'AI Agents',
#  'AI Researchers',
#  'AI Researchers Trying To Build Knowledge']

# %%
relations = graph.get_adjacent_edges(nodes[0])
print(relations)
# Out:
# {'outgoing': [Relation(node_1=Node(id='35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3', name='AI Research', type='Node', metadata={}), edge=Edge(id='4937ca29d5c3c3189e0dc6cd8fa1f2eca307f114f08e9046429162a119860ed2', name='Conducted With Limited Computation', type='Edge', metadata={'document_id': 'b9ac056066f1d8107fc8ebbd9871349d28f73d62f348deb5c203bce91b206ba1'}), node_2=Node(id='5a9ff1e640294c3ae5f3f2b69516a6c2af5776f5e3e262e04be2055925ab9ef8', name='Constant Computation', type='Node', metadata={}))], 'incoming': [Relation(node_1=Node(id='63158218a6b8ea29bfb465c263af15671f8198e16bb1605370e9480ea43e8f08', name='Human Knowledge', type='Node', metadata={}), edge=Edge(id='999aa24bc012ca8a57b6b03951b2b6ec8c327a43e46b13e6dad8bc9a869a28b5', name='Leveraged In AI Research', type='Edge', metadata={'document_id': 'b9ac056066f1d8107fc8ebbd9871349d28f73d62f348deb5c203bce91b206ba1'}), node_2=Node(id='35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3', name='AI Research', type='Node', metadata={})), Relation(node_1=Node(id='e72390b4f750cabf73d01f0e3d5099731cdea87dba977a74d6848296a89ed0a1', name='Computation', type='Node', metadata={}), edge=Edge(id='93382f88383916c2fae43ac53b139d2d268d71cd356806b296d0ff9c48eced7b', name='Leveraged In AI Research', type='Edge', metadata={'document_id': 'b9ac056066f1d8107fc8ebbd9871349d28f73d62f348deb5c203bce91b206ba1'}), node_2=Node(id='35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3', name='AI Research', type='Node', metadata={}))], 'records': [<Record source=<Node element_id='4:746d30e9-4bc3-4a04-979a-1b9328241af7:77' labels=frozenset({'Node'}) properties={'name': 'AI Research', 'id': '35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3'}> edge=<Relationship element_id='5:746d30e9-4bc3-4a04-979a-1b9328241af7:137' nodes=(<Node element_id='4:746d30e9-4bc3-4a04-979a-1b9328241af7:77' labels=frozenset({'Node'}) properties={'name': 'AI Research', 'id': '35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3'}>, <Node element_id='4:746d30e9-4bc3-4a04-979a-1b9328241af7:96' labels=frozenset({'Node'}) properties={'name': 'Constant Computation', 'id': '5a9ff1e640294c3ae5f3f2b69516a6c2af5776f5e3e262e04be2055925ab9ef8'}>) type='Edge' properties={'name': 'Conducted With Limited Computation', 'id': '4937ca29d5c3c3189e0dc6cd8fa1f2eca307f114f08e9046429162a119860ed2', 'document_id': 'b9ac056066f1d8107fc8ebbd9871349d28f73d62f348deb5c203bce91b206ba1'}> target=<Node element_id='4:746d30e9-4bc3-4a04-979a-1b9328241af7:96' labels=frozenset({'Node'}) properties={'name': 'Constant Computation', 'id': '5a9ff1e640294c3ae5f3f2b69516a6c2af5776f5e3e262e04be2055925ab9ef8'}>>, <Record target=<Node element_id='4:746d30e9-4bc3-4a04-979a-1b9328241af7:77' labels=frozenset({'Node'}) properties={'name': 'AI Research', 'id': '35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3'}> edge=<Relationship element_id='5:746d30e9-4bc3-4a04-979a-1b9328241af7:139' nodes=(<Node element_id='4:746d30e9-4bc3-4a04-979a-1b9328241af7:79' labels=frozenset({'Node'}) properties={'name': 'Human Knowledge', 'id': '63158218a6b8ea29bfb465c263af15671f8198e16bb1605370e9480ea43e8f08'}>, <Node element_id='4:746d30e9-4bc3-4a04-979a-1b9328241af7:77' labels=frozenset({'Node'}) properties={'name': 'AI Research', 'id': '35ace33536b5c5d356b9074c0105fc45002fddd929cde3d17bbf8c565b8e5ef3'}>) type='Edge' properties={'name': 'Leveraged In AI Research', 'id': '999aa24bc012ca8a57b6b03951b2b6ec8c327a43e46b13e6dad8bc9a869a28b5', 'document_id': 'b9ac056066f1d8107fc8ebbd9871349d28f73d62f348deb5c203bce91b206ba1'}> source=<Node element_id='4:746d30e9-4bc3-4a04-979a-1b9328241af7:79' labels=frozenset({'Node'}) properties={'name': 'Human Knowledge', 'id': '63158218a6b8ea29bfb465c263af15671f8198e16bb1605370e9480ea43e8f08'}>>, <Record target=<Node element_id='4:746d30e9-4bc3-4a04-979a-1b9328241af7:77' labels=frozenset({'Node'}) properties={'name': 'AI Research', 'id': '35ace33536b5c5d356b9074c0105fc45002fddd929c ...

# %%
outgoing = relations['outgoing']
incoming = relations['incoming']
records = relations['records']

# %%
for r in outgoing:
    print(r)
